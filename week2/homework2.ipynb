# %% [markdown]
# # 2. Tapes and opeartions — homework

# %% [markdown]
# ### Exercise 2.1
# Create a long positive integer. Find the number of zeros. Hint: change the number to a string.

# %%
#create large random integer
from random import randint
integer = randint(10**1000, 10**1001)
print(integer)

#create a variablu to hold the number of zeros
n_zeros = 0

#iterate throu the decimal expansion, upon encountering a zero — update the counter
for c in str(integer):
    if c == '0':
        n_zeros += 1 

#report results     
print(f"\nThe inetegr provides has {n_zeros} zeros in it's decimal expansion")
# Out:
# ...
#
# The inetegr provides has 89 zeros in it's decimal expansion

# %% [markdown]
# ### Exercise 2.2 (bool)

# %% [markdown]
# Explain the results.

# %%
x = 5
x == 5 and 3 + 8
# Out:
# 11
