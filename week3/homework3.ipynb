# %% [markdown]
# # 3. Statements — homework

# %% [markdown]
# ### Exercise 3.1
#
# For a given word (you may use your name), print it in squares.
#
# If word = "Python", then the result is
#
# ```
# +---+---+---+---+---+---+
# | P | y | t | h | o | n |
# +---+---+---+---+---+---+
# ```

# %%
word = 'Paweł'

#prepare top and bottom lines
tb = '+' + ('---+')*len(word)

#prepare the middle line
middle = '|'
for ch in word:
    middle = middle + ' ' + ch + ' |' #and 'end of square' after every character

print(tb, middle, tb, sep='\n')
# Out:
# +---+---+---+---+---+
# | P | a | w | e | ł |
# +---+---+---+---+---+

# %% [markdown]
# ### Exercise 3.2
#
# Make a loop over integer numbers from 1 to 40.
#
# * If x is divided by 5 then print a message 'x is divided by 5'.
#
# * If x is divided by 7 then print a message 'x is divided by 7'.
#
# * If x is divided by 5 and 7 then print a message 'x is divided by 5 and 7'.
#
# * Skip x = 13.
#
# * If x is not divided by 5 and x is not divided by 7 then print a message 'x is not important'.
#
# Prepare two solutions with 'while' and 'for' loops.

# %%
#solution with for

for n in range(1, 41):
    if n == 13:
        continue
    elif n % 5 == 0 and n % 7 == 0:
        print(f'{n} is divided by 5 and 7')
    elif n % 5 == 0:
        print(f'{n} is divided by 5')
    elif n % 7 == 0:
        print(f'{n} is divided by 7')
    else:
        print(f'{n} is not importatnt')
# Out:
# 1 is not importatnt
# 2 is not importatnt
# 3 is not importatnt
# 4 is not importatnt
# 5 is divided by 5
# 6 is not importatnt
# 7 is divided by 7
# 8 is not importatnt
# 9 is not importatnt
# 10 is divided by 5
# 11 is not importatnt
# 12 is not importatnt
# 14 is divided by 7
# 15 is divided by 5
# 16 is not importatnt
# 17 is not importatnt
# 18 is not importatnt
# 19 is not importatnt
# 20 is divided by 5
# 21 is divided by 7
# 22 is not importatnt
# 23 is not importatnt
# 24 is not importatnt
# 25 is divided by 5
# 26 is not importatnt
# 27 is not importatnt
# 28 is divided by 7
# 29 is not importatnt
# 30 is divided by 5
# 31 is not importatnt
# 32 is not importatnt
# 33 is not importatnt
# 34 is not importatnt
# 35 is divided by 5 and 7
# 36 is not importatnt
# 37 is not importatnt
# 38 is not importatnt
# 39 is not importatnt
# 40 is divided by 5

# %%
#solution with while

n = 0
while n < 40:
    n += 1
    if n == 13:
        continue
    elif n % 5 == 0 and n % 7 == 0:
        print(f'{n} is divided by 5 and 7')
    elif n % 5 == 0:
        print(f'{n} is divided by 5')
    elif n % 7 == 0:
        print(f'{n} is divided by 7')
    else:
        print(f'{n} is not importatnt')
# Out:
# 1 is not importatnt
# 2 is not importatnt
# 3 is not importatnt
# 4 is not importatnt
# 5 is divided by 5
# 6 is not importatnt
# 7 is divided by 7
# 8 is not importatnt
# 9 is not importatnt
# 10 is divided by 5
# 11 is not importatnt
# 12 is not importatnt
# 14 is divided by 7
# 15 is divided by 5
# 16 is not importatnt
# 17 is not importatnt
# 18 is not importatnt
# 19 is not importatnt
# 20 is divided by 5
# 21 is divided by 7
# 22 is not importatnt
# 23 is not importatnt
# 24 is not importatnt
# 25 is divided by 5
# 26 is not importatnt
# 27 is not importatnt
# 28 is divided by 7
# 29 is not importatnt
# 30 is divided by 5
# 31 is not importatnt
# 32 is not importatnt
# 33 is not importatnt
# 34 is not importatnt
# 35 is divided by 5 and 7
# 36 is not importatnt
# 37 is not importatnt
# 38 is not importatnt
# 39 is not importatnt
# 40 is divided by 5

# %% [markdown]
# ### Exercise 3.3
#
# Create the following variables:
#
# ```
# n = 2022
# x = math.pi   # save with 5 digits after a dot (import 'math' first!)
# word = "Python"
# polish = "książka"   # 'book' in English
# ```
# Write the variables to a text file "vars.txt",
# one line for one variable.
#
# Print the file content on the screen.

# %%
import math

#items
n = 2022
x = math.pi
word = "Python"
polish = "książka"

#write to file
with open('vars.txt', 'w') as f:
    f.write(f'{n}\n{x:.5f}\n{word}\n{polish}')

#read form file
with open('vars.txt', 'r') as f:
    print(f.read())
# Out:
# 2022
# 3.14159
# Python
# książka
